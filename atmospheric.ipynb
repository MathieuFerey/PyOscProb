# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import astropy.units as u
import matplotlib.pyplot as plt

import src.const as const

from tqdm import tqdm

from src.oscillation import Oscillator
from src.oscillation_parameters import OscillationParameters
from src.earth import Slab, Layer, EarthModel
from src.atm_utils import *

axis_size=15
legend_size=13
tick_size=13

plt.rc('axes',labelsize=axis_size)
plt.rc('legend',fontsize=legend_size)
plt.rc('xtick',labelsize=tick_size)
plt.rc('ytick',labelsize=tick_size)
plt.rc('font',size=legend_size)
plt.rc("figure", figsize=(8, 6))

plt.rcParams["text.usetex"] = True
plt.rcParams["font.family"] = "serif"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
Thetaz = np.linspace(0, np.pi, 100)
earth = EarthModel()


# Show Earth and slabs
earth.plot_slabs(Thetaz)

# %%
# Vectorized version
osc_params = OscillationParameters()
earth = EarthModel()

Thetaz = np.linspace(0, np.pi, 200)
E = np.logspace(-1, 2, 200) * u.GeV

P_mu = compute_oscillograms("mu", Thetaz, E, earth, osc_params)
# Out:
# Precomputing slabs for all thetas...
# 100%|██████████| 200/200 [00:00<00:00, 448.80it/s]

# %%
plot_oscillograms(Thetaz, E, P_mu, "mu", ["e", "mu", "tau"])
